# %% [markdown]
# # Week 7 & 8

# %% [markdown]
# ## Data Cleaning & Transforming

# %% [markdown]
# ### 'So Much Data Candy, Seriously'

# %%
import pandas as pd
import numpy as np

# %%
candy_df = pd.read_excel('/Users/theranmeadows/Desktop/dsc540datapreparation/week7&8/candyhierarchy2017.xlsx')
candy_df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
# ...

# %% [markdown]
# #### Chapter 7

# %%
candy_df.shape
# Out:
# (2460, 120)

# %% [markdown]
# ##### Filter Out Missing Data

# %%
# Get the count of how many Nans each column has
nan_count = candy_df.isna().sum()

# This will sort the top most columns with Nans
nan_count.sort_values(ascending = False).head(10)
# Out:
# Unnamed: 113                 2451
# Q12: MEDIA [Yahoo]           2393
# Q12: MEDIA [Daily Dish]      2375
# Q12: MEDIA [ESPN]            2361
# Q9: OTHER COMMENTS           2074
# Q8: DESPAIR OTHER            1743
# Q7: JOY OTHER                1549
# Q12: MEDIA [Science]         1098
# Q6 | JoyJoy (Mit Iodine!)    1026
# Q6 | Maynards                1024
# dtype: int64

# %%
# The unnamed column has only 9 values of the 2460 rows. So it must be dropped.
candy_df = candy_df.drop('Unnamed: 113', axis = 1)
candy_df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
total_rows = candy_df.shape[0]
total_rows
# Out:
# 2460

# %%
# I will keep rows that have 50 or more of the columns filled in
candy_df = candy_df.dropna(thresh = 50)
candy_df.shape
# Out:
# (1784, 119)

# %%
candy_df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1     90272821             No       Male      44        USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male     NaN         NaN
# 7     90272854             No       Male      33      canada
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                               NM                MEH
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                              NaN                JOY
# 7                          ontario                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# ...

# %% [markdown]
# #### Replace Values

# %%
# Values in the Age column that are not ints or realistic values will be filled in with the median age
candy_df['Q3: AGE'].unique()
# Out:
# array([44, 40, 23, nan, 33, 53, 56, 64, 43, 37, 59, 48, 45, 49, 34, 35,
#        38, 58, 50, 47, 52, 63, 65, 41, 31, 61, 46, 54, 62, 29, 42, 36, 32,
#        28, 69, 67, 39, 30, 25, 22, 51, 70, 24, 27, 18, 19, 'Old enough',
#        57, 66, 12, 'Many', 60, 55, '?', 21, 11, 'no', 68, 20, 6, 10, 71,
#        90, 13, 26, '45-55', 312, 72, 99, 'hahahahaha', 9, 88, 74, 102,
#        'older than dirt', 15, 8, 75, 17, 'Enough', 'See question 2',
#        '24-50', 7, 14, 'Over 50', 76, 100, 1000, 16, '46 Halloweens.',
#        'ancient', 77, 'OLD', 'MY NAME JEFF', 4, 73, 'old enough',
#        'I can remember when Java was a cool new language'], dtype=object)

# %%
type(candy_df.iloc[0,3])
# Out:
# int

# %%
for age in candy_df['Q3: AGE']:
    if type(age) == 'str':
        age = age.replace(age, 0)

# %%
# def clean_age(column):
#     for value in column:
#         if type(value) == 'str':
#             column = column.replace(value, 0)
#     # return type(value)
#     return column.unique()

# %%
clean_age(candy_df['Q3: AGE'])
# Out:
# array([44, 40, 23, nan, 33, 53, 56, 64, 43, 37, 59, 48, 45, 49, 34, 35,
#        38, 58, 50, 47, 52, 63, 65, 41, 31, 61, 46, 54, 62, 29, 42, 36, 32,
#        28, 69, 67, 39, 30, 25, 22, 51, 70, 24, 27, 18, 19, 'Old enough',
#        57, 66, 12, 'Many', 60, 55, '?', 21, 11, 'no', 68, 20, 6, 10, 71,
#        90, 13, 26, '45-55', 312, 72, 99, 'hahahahaha', 9, 88, 74, 102,
#        'older than dirt', 15, 8, 75, 17, 'Enough', 'See question 2',
#        '24-50', 7, 14, 'Over 50', 76, 100, 1000, 16, '46 Halloweens.',
#        'ancient', 77, 'OLD', 'MY NAME JEFF', 4, 73, 'old enough',
#        'I can remember when Java was a cool new language'], dtype=object)

# %%
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('Old enough', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('Many', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('?', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('no', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('45-55', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('hahahahaha', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace(312, 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace(102, 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('older than dirt', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('Enough', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('See question 2', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('24-50', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('Over 50', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('46 Halloweens.', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('ancient', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('OLD', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('MY NAME JEFF', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('old enough', 0)
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].replace('I can remember when Java was a cool new language', 0)

# %%
candy_df['Q3: AGE'].unique()
# Out:
# array([  44.,   40.,   23.,   nan,   33.,   53.,   56.,   64.,   43.,
#          37.,   59.,   48.,   45.,   49.,   34.,   35.,   38.,   58.,
#          50.,   47.,   52.,   63.,   65.,   41.,   31.,   61.,   46.,
#          54.,   62.,   29.,   42.,   36.,   32.,   28.,   69.,   67.,
#          39.,   30.,   25.,   22.,   51.,   70.,   24.,   27.,   18.,
#          19.,    0.,   57.,   66.,   12.,   60.,   55.,   21.,   11.,
#          68.,   20.,    6.,   10.,   71.,   90.,   13.,   26.,   72.,
#          99.,    9.,   88.,   74.,   15.,    8.,   75.,   17.,    7.,
#          14.,   76.,  100., 1000.,   16.,   77.,    4.,   73.])

# %%
# will set the columns type to numeric to check for any values left out
candy_df['Q3: AGE'] = pd.to_numeric(candy_df['Q3: AGE'])

# %%
# find the median age useing the numeric values
median_age = candy_df['Q3: AGE'].median()
median_age
# Out:
# 42.0

# %%
#fill in the nan values with the median age
candy_df['Q3: AGE'] = candy_df['Q3: AGE'].fillna(median_age)

# %%
# check for any lingering nan values
candy_df['Q3: AGE'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Chapter 8

# %% [markdown]
# #### Create A Hieratchial Index

# %%
candy_df_heir = candy_df.set_index(['Q1: GOING OUT?', 'Q2: GENDER', 'Internal ID'])

# %%
candy_df_heir
# Out:
#                                        Q3: AGE Q4: COUNTRY  \
# Q1: GOING OUT? Q2: GENDER Internal ID
# No             Male       90272821        44.0        USA
#                           90272840        40.0          us
#                           90272841        23.0         usa
#                           90272852        42.0         NaN
#                           90272854        33.0      canada
# ...                                        ...         ...
#                Female     90314022        26.0         USA
#                Male       90314359        24.0         USA
#                Female     90314580        33.0         USA
#                           90314634        26.0        USA
#                           90314802        66.0         usa
#
#                                       Q5: STATE, PROVINCE, COUNTY, ETC  \
# Q1: GOING OUT? Q2: GENDER Internal ID
# No             Male       90272821                                  NM
# ...

# %% [markdown]
# #### Pivot the Data

# %%
candy_df_pivoted =  candy_df.pivot(index = 'Internal ID', columns = 'Q2: GENDER', values = 'Q3: AGE')

# %%
candy_df_pivoted
# Out:
# Q2: GENDER   NaN  Female  I'd rather not say  Male  Other
# Internal ID
# 90272821     NaN     NaN                 NaN  44.0    NaN
# 90272840     NaN     NaN                 NaN  40.0    NaN
# 90272841     NaN     NaN                 NaN  23.0    NaN
# 90272852     NaN     NaN                 NaN  42.0    NaN
# 90272854     NaN     NaN                 NaN  33.0    NaN
# ...          ...     ...                 ...   ...    ...
# 90314022     NaN    26.0                 NaN   NaN    NaN
# 90314359     NaN     NaN                 NaN  24.0    NaN
# 90314580     NaN    33.0                 NaN   NaN    NaN
# 90314634     NaN    26.0                 NaN   NaN    NaN
# 90314802     NaN    66.0                 NaN   NaN    NaN
#
# [1784 rows x 5 columns]

# %% [markdown]
# ### Chapter 10

# %% [markdown]
# #### Grouping with Index Levels

# %%
candy_df_heir.groupby(level = 'Q2: GENDER', axis = 0).count()
# Out:
#                     Q3: AGE  Q4: COUNTRY  Q5: STATE, PROVINCE, COUNTY, ETC  \
# Q2: GENDER
# Female                  612          610                               604
# I'd rather not say       60           54                                54
# Male                   1076         1068                              1055
# Other                    26           26                                25
#
#                     Q6 | 100 Grand Bar  \
# Q2: GENDER
# Female                             579
# I'd rather not say                  59
# Male                              1038
# Other                               22
#
#                     Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q2: GENDER
# Female                                                            589
# I'd rather not say                                                 60
# Male                                                             1037
# ...

# %% [markdown]
# #### Cross Tabs

# %%
candy_df_crosstab = pd.crosstab(candy_df['Q3: AGE'], candy_df['Q2: GENDER'])

# %%
candy_df_crosstab
# Out:
# Q2: GENDER  Female  I'd rather not say  Male  Other
# Q3: AGE
# 0.0              4                   4     9      2
# 4.0              0                   0     1      0
# 6.0              1                   0     0      0
# 7.0              0                   0     1      0
# 8.0              1                   0     1      0
# ...            ...                 ...   ...    ...
# 88.0             0                   1     0      0
# 90.0             0                   1     1      0
# 99.0             0                   1     0      0
# 100.0            0                   1     0      0
# 1000.0           0                   1     0      0
#
# [79 rows x 4 columns]

# %% [markdown]
# ### Chapter 11

# %%
boing_candy_df = pd.read_excel('/Users/theranmeadows/Desktop/dsc540datapreparation/week7&8/BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx')
boing_candy_df.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
# ...

# %% [markdown]
# #### Convert between string and date time

# %%
boing_candy_df['date_str'] = boing_candy_df['Timestamp'].astype(str)
boing_candy_df.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
# ...

# %% [markdown]
# #### Generate date range

# %%
# find the number of data entries
date_entries_count = boing_candy_df.shape[0]
date_entries_count
# Out:
# 1259

# %%
boing_candy_df['date_range'] = pd.date_range('2016-10-24', periods = date_entries_count )
boing_candy_df.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
# ...
